# %% [markdown]
# ## Algerian Forest Fires Dataset
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.

# %% [markdown]
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np

import plotly.express as px
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header= 1)
# header is given so that it can take second row as the columns row

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df[df.isnull()]
# Out:
#      day month year Temperature   RH   Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 0    NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..   ...   ...  ...         ...  ...  ...   ...  ...  ...  ...  ...  ...  ...
# 241  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 242  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 243  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 244  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 245  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     Classes
# 0         NaN
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top      01    07  2012          35   55   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  128         9
# top     0.4   fire
# freq     12       131

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# ## here converting the different regions into lablels
#
# 0 for the Bejaia Region <br>
# 1 for the Sidi-Bel Abbes

# %%
# you must know how to use the loc



df.loc[:122, 'Region'] = 0
df.loc[122: , 'Region'] = 1

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df[df.isnull().any(axis= 1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN     1.0
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN     1.0

# %%
# now let's drop this sidi_Bel Abbes row

df_copy = df.drop(index= 122, axis = 0)

# %%
df_copy[df_copy.isnull().any(axis=1)]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 167  14    07  2012          37  37  18   0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes    Region
# 167  fire          NaN     1.0

# %%
df_copy.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
df_copy['Classes  '] = df_copy['Classes  '].fillna(df_copy['Classes  '].mode()[0])

# mode always return a series of values that's why you need to give the index as well

# because there could be more than one node 
# normally the highest count mode is on the top

# %%
df_copy.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df_copy.duplicated().sum()  # there are no duplicates in the dataset
# Out:
# np.int64(0)

# %%
# let's check the columns names


df_copy.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# here there are some splaces left i need to remove all those extra space

df_copy.columns = df_copy.columns.str.strip()

# %%
df_copy.columns # removed all the extra space
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df_copy['Classes'].unique()  # there are also some spaces here
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'Classes  ', 'not fire     ', 'not fire    '], dtype=object)

# %%
# i acutally need to map these values into 0 and 1 here

# let me write some program here

def str_replace(x):
    if 'not fire'  in x:
        return 0
    if 'fire' in x:
        return 1
    return x

df_copy['Classes'] = df_copy['Classes'].apply(str_replace)

# %%
df_copy
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI Classes  Region
# 0    0.5       0     0.0
# 1    0.4       0     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df_copy['Rain'].unique()
# Out:
# array(['0', '1.3', '13.1', '2.5', '0.2', '1.2', '0.5', '3.1', '0.7',
#        '0.6', '0.3', '0.1', '0.4', '1', '1.4', '0.8', '16.8', '7.2',
#        '10.1', '3.8', '0.9', '1.8', '4.6', '8.3', '5.8', 'Rain ', '4',
#        '2', '4.7', '8.7', '4.5', '1.1', '1.7', '2.2', '6', '1.9', '2.9',
#        '4.1', '6.5', '4.4'], dtype=object)

# %%
df_copy['Rain'] = pd.to_numeric(df_copy['Rain'], errors='coerce')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         244 non-null    float64
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(2), object(13)
# memory usage: 30.6+ KB

# %%
df_copy['Rain'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df_copy['Rain'] = df_copy['Rain'].fillna(df_copy['Rain'].median())
# here data is positively skewed that's why we are using median here

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    float64
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(2), object(13)
# memory usage: 30.6+ KB

# %%
df_copy['FFMC'].unique()
# Out:
# array(['65.7', '64.4', '47.1', '28.6', '64.8', '82.6', '88.2', '86.6',
#        '52.9', '73.2', '84.5', '84', '50', '59', '49.4', '36.1', '37.3',
#        '56.9', '79.9', '59.8', '81', '79.1', '81.4', '85.9', '86.7',
#        '86.8', '89', '89.1', '88.7', '59.9', '55.7', '63.1', '80.1', '87',
#        '80', '85.6', '66.6', '81.1', '75.1', '81.8', '73.9', '60.7',
#        '72.6', '82.8', '85.4', '88.1', '73.4', '68.2', '70', '84.3',
#        '89.2', '90.3', '86.5', '87.2', '78.8', '78', '76.6', '85', '86.4',
#        '77.1', '87.4', '88.9', '81.3', '82.4', '80.2', '89.3', '89.4',
#        '88.3', '88.6', '89.5', '85.8', '84.9', '90.1', '72.7', '52.5',
#        '46', '30.5', '42.6', '68.4', '80.8', '75.8', '69.6', '62', '56.1',
#        '58.5', '71', '40.9', '47.4', '44.9', '78.1', '87.7', '83.8',
#        '87.8', '77.8', '73.7', '68.3', '48.6', '82', '85.7', '77.5', '45',
#        'FFMC', '57.1', '48.7', '79.4', '83.7', '71.4', '90.6', '72.3',
# ...

# %%
df_copy['FFMC'] = pd.to_numeric(df_copy['FFMC'], errors= 'coerce')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(3), object(12)
# memory usage: 30.6+ KB

# %%
df_copy['Temperature'] = pd.to_numeric(df_copy['Temperature'], errors= 'coerce')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  244 non-null    float64
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(4), object(11)
# memory usage: 30.6+ KB

# %%
df_copy['Temperature'].plot(kind='kde')
# here data is normally is distibuted that's why are using the mean
# Out:
# <Axes: ylabel='Density'>

# %%
df_copy['Temperature'] = df_copy['Temperature'].fillna(df_copy['Temperature'].mean())

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    float64
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(4), object(11)
# memory usage: 30.6+ KB

# %%
df_copy['Classes'].unique()
# Out:
# array([0, 1, 'Classes  '], dtype=object)

# %%
# if i really need to find the correlationns between values then i have to convert these values in the numberic i don't have a choice

df_copy['Classes'] = pd.to_numeric(df_copy['Classes'], errors= 'coerce')

# %%
df_copy['Classes'].plot(kind='kde') # here you can see it's a categorical data that's means 
# i need to use the mode here
# Out:
# <Axes: ylabel='Density'>

# %%
df_copy['Classes'] = df_copy['Classes'].fillna(df_copy['Classes'].mode()[0])

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    float64
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    float64
#  14  Region       245 non-null    float64
# dtypes: float64(5), object(10)
# memory usage: 30.6+ KB

# %%
df_copy['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '7.1 ', '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6',
#        '15', '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8',
#        '0.6', '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1',
#        '1.3', '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6',
#        '9.9', '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1',
#        '17.2', '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7',
#        '13.2', '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1',
#        'FWI', '1', '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5',
#        '12', '6.4', '5.2', '3', '9.6', '4.7', 'fire   ', '14.1', '9.1',
#        '13', '17.3', '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5',
#        '12.6', '12.7', '21.6', '18.8', '10.5', '5.5', '14.8', '24',
#        '26.3', '12.2', '18.1', '24.5', '26.9', '31.1', '30.3', '26.1',
# ...

# %%
df_copy.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain  FFMC  DMC  DC  ISI  BUI  \
# 123  day  month  year    32.172131   RH   Ws   0.0   NaN  DMC  DC  ISI  BUI
#
#      FWI  Classes  Region
# 123  FWI      1.0     1.0

# %%
# here i need to delete that's whole row for easy convertion i didn't took care of of it earlier


df_copy = df_copy.drop(123).reset_index(drop = True)

# %%
df_copy.iloc[[123]]
# Out:
#     day month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 123  02    06  2012         30.0  73  13   4.0  55.7  2.7  7.8  0.6  2.9  0.2
#
#      Classes  Region
# 123      0.0     1.0

# %%
df_copy['BUI'].unique()
# Out:
# array(['3.4', '3.9', '2.7', '1.7', '7', '10.9', '13.5', '10.5', '12.6',
#        '15.8', '17.7', '6.7', '4.4', '3', '2.2', '1.6', '2.4', '5.3',
#        '5.1', '8.4', '9.7', '11.5', '14.9', '18.3', '21.6', '25.8',
#        '29.7', '23.8', '28.3', '2.9', '2.8', '5.7', '9.1', '12.5', '12.1',
#        '15.4', '7.4', '5.8', '8.1', '9.2', '11.7', '5.9', '8.3', '11.1',
#        '14.2', '18.2', '16.5', '22.4', '21.7', '14.7', '18.5', '23.9',
#        '29.4', '32.1', '35', '37.4', '41.2', '4.7', '5.5', '8.2', '17.2',
#        '14.1', '17.9', '21.9', '25.5', '20.7', '24.4', '27.2', '22',
#        '17.6', '22.9', '27.5', '31.3', '34.7', '38.8', '43.1', '47.5',
#        '50.9', '54.7', '57.1', '59.3', '62.9', '67.4', '1.8', '1.1',
#        '5.6', '2.6', '3.7', '1.4', '4.2', '7.7', '11.3', '16', '19.2',
#        '12.9', '9.6', '6.2', '9', '6.8', '6.5', '9.3', '10.7', '7.3',
#        '13.1', '18', '21.2', '6.1', '7.1', '4.1', '3.8', '9.9', '12.7',
# ...

# %%
df_copy
# Out:
#     day month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012         29.0  57  18   0.0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012         29.0  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012         26.0  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012         25.0  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012         27.0  77  16   0.0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...          ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012         30.0  65  14   0.0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012         28.0  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012         27.0  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012         24.0  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012         24.0  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI  Classes  Region
# 0    0.5      0.0     0.0
# ...

# %%
df_copy['Ws'].unique()
# Out:
# array(['18', '13', '22', '16', '14', '15', '12', '19', '21', '20', '17',
#        '26', '11', '10', '9', '8', '6', '29'], dtype=object)

# %%
df_copy['RH'].unique()
# Out:
# array(['57', '61', '82', '89', '77', '67', '54', '73', '88', '79', '65',
#        '81', '84', '78', '80', '55', '62', '66', '64', '53', '47', '50',
#        '68', '75', '76', '63', '69', '70', '59', '48', '45', '60', '51',
#        '52', '58', '86', '74', '71', '49', '44', '41', '42', '90', '87',
#        '72', '46', '37', '36', '56', '43', '83', '29', '34', '33', '35',
#        '39', '31', '21', '40', '24', '38', '26'], dtype=object)

# %%
df_copy['Temperature'].unique()
# Out:
# array([29., 26., 25., 27., 31., 33., 30., 28., 32., 34., 35., 36., 37.,
#        22., 24., 38., 39., 40., 42.])

# %%
df_copy[['Temperature','RH', 'Ws', 'Classes', 'Region']] = df_copy[['Temperature','RH', 'Ws', 'Classes', 'Region']].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 28.7+ KB

# %%
df_copy.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
cols = [ 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']

# df_copy[cols] = pd.to_numeric(cols, errors= 'coerce')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 28.7+ KB

# %%
df_copy['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '7.1 ', '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6',
#        '15', '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8',
#        '0.6', '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1',
#        '1.3', '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6',
#        '9.9', '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1',
#        '17.2', '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7',
#        '13.2', '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1',
#        '1', '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5', '12',
#        '6.4', '5.2', '3', '9.6', '4.7', 'fire   ', '14.1', '9.1', '13',
#        '17.3', '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5', '12.6',
#        '12.7', '21.6', '18.8', '10.5', '5.5', '14.8', '24', '26.3',
#        '12.2', '18.1', '24.5', '26.9', '31.1', '30.3', '26.1', '16',
# ...

# %%
df_copy['FWI'] = pd.to_numeric(df_copy['FWI'], errors= 'coerce')

# %%
df_copy['FWI'].plot(kind='kde')
# positively skewed that's why filling it with median values
# Out:
# <Axes: ylabel='Density'>

# %%
df_copy['FWI'] = df_copy['FWI'].fillna(df_copy['FWI'].median())

# %%
df_copy['BUI'].unique()
# Out:
# array(['3.4', '3.9', '2.7', '1.7', '7', '10.9', '13.5', '10.5', '12.6',
#        '15.8', '17.7', '6.7', '4.4', '3', '2.2', '1.6', '2.4', '5.3',
#        '5.1', '8.4', '9.7', '11.5', '14.9', '18.3', '21.6', '25.8',
#        '29.7', '23.8', '28.3', '2.9', '2.8', '5.7', '9.1', '12.5', '12.1',
#        '15.4', '7.4', '5.8', '8.1', '9.2', '11.7', '5.9', '8.3', '11.1',
#        '14.2', '18.2', '16.5', '22.4', '21.7', '14.7', '18.5', '23.9',
#        '29.4', '32.1', '35', '37.4', '41.2', '4.7', '5.5', '8.2', '17.2',
#        '14.1', '17.9', '21.9', '25.5', '20.7', '24.4', '27.2', '22',
#        '17.6', '22.9', '27.5', '31.3', '34.7', '38.8', '43.1', '47.5',
#        '50.9', '54.7', '57.1', '59.3', '62.9', '67.4', '1.8', '1.1',
#        '5.6', '2.6', '3.7', '1.4', '4.2', '7.7', '11.3', '16', '19.2',
#        '12.9', '9.6', '6.2', '9', '6.8', '6.5', '9.3', '10.7', '7.3',
#        '13.1', '18', '21.2', '6.1', '7.1', '4.1', '3.8', '9.9', '12.7',
# ...

# %%
df_copy['BUI'] = df_copy['BUI'].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 28.7+ KB

# %%
df_copy['DMC'].unique()
# Out:
# array(['3.4', '4.1', '2.5', '1.3', '3', '5.8', '9.9', '12.1', '7.9',
#        '9.5', '12.5', '13.8', '6.7', '4.6', '1.7', '1.1', '1.9', '4.5',
#        '6.3', '7', '8.2', '11.2', '14.2', '17.8', '21.6', '25.5', '18.4',
#        '22.9', '2.4', '2.6', '7.6', '10.9', '9.7', '7.7', '6', '8.1',
#        '7.8', '5.2', '9.4', '12', '12.3', '18.5', '16.4', '10.5', '9.6',
#        '17.1', '22.2', '24.4', '26.7', '28.5', '31.9', '4.8', '5.7',
#        '11.1', '13', '15.5', '11.3', '14.8', '18.6', '21.7', '15.6', '19',
#        '11.7', '16', '20', '23.2', '25.9', '29.6', '33.5', '37.6', '40.5',
#        '43.9', '45.6', '47', '50.2', '54.2', '25.2', '8.7', '0.7', '1.2',
#        '3.6', '3.2', '2.1', '2.2', '0.9', '6.4', '9.8', '13.5', '16.5',
#        '10.6', '5.5', '8.3', '7.1', '2.9', '2.7', '8.4', '8.5', '13.3',
#        '18.2', '21.3', '11.4', '7.2', '4.2', '3.9', '4.4', '3.8', '10',
#        '12.8', '20.9', '27.2', '17.9', '13.6', '18.7', '8', '12.6',
# ...

# %%
df_copy['DMC'] = df_copy['DMC'].astype(float)

# %%
df_copy['DC'].unique()
# Out:
# array(['7.6', '7.1', '6.9', '14.2', '22.2', '30.5', '38.3', '38.8',
#        '46.3', '54.3', '61.4', '17', '7.8', '7.4', '8', '16', '27.1',
#        '31.6', '39.5', '47.7', '55.8', '63.8', '71.8', '80.3', '88.5',
#        '84.4', '92.8', '8.6', '8.3', '9.2', '18.5', '27.9', '37', '40.4',
#        '49.8', '9.3', '18.7', '27.7', '37.2', '22.9', '25.5', '34.1',
#        '43.1', '52.8', '62.1', '71.5', '79.9', '71.3', '79.7', '88.7',
#        '98.6', '108.5', '117.8', '127', '136', '145.7', '10.2', '10',
#        '19.8', '29.7', '39.1', '48.6', '47', '57', '67', '77', '75.1',
#        '85.1', '94.7', '92.5', '90.4', '100.7', '110.9', '120.9', '130.6',
#        '141.1', '151.3', '161.5', '171.3', '181.3', '190.6', '200.2',
#        '210.4', '220.4', '180.4', '8.7', '7.5', '7', '15.7', '24', '32.2',
#        '30.1', '8.4', '8.9', '16.6', '7.3', '24.3', '33.1', '41.3',
#        '49.3', '57.9', '41.4', '30.4', '15.2', '7.7', '16.3', '24.9',
# ...

# %%
# it was throwing an error because 14.6 9
def removing_space(x):
    if isinstance(x,str):
        return x.replace(" ", '')
    
    return x




df_copy['DC'] = df_copy['DC'].apply(removing_space).astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 28.7+ KB

# %%
df_copy['ISI'].unique()
# Out:
# array(['1.3', '1', '0.3', '0', '1.2', '3.1', '6.4', '5.6', '0.4', '4',
#        '4.8', '0.5', '0.7', '2.5', '0.9', '2.6', '2.4', '3.3', '5.7',
#        '6.7', '9.2', '7.6', '2.2', '7.2', '1.1', '0.8', '2.7', '2.8', '6',
#        '1.5', '3', '1.4', '3.2', '4.6', '7.7', '5.2', '1.8', '10', '8.7',
#        '4.7', '6.8', '2', '1.7', '5.5', '6.9', '7.4', '7.1', '5.9', '3.7',
#        '9.7', '8.8', '9.9', '10.4', '9', '8.2', '4.4', '7.3', '12.5',
#        '0.6', '0.2', '0.1', '2.1', '1.9', '6.2', '7.8', '4.5', '5.4',
#        '8.4', '13.4', '5', '1.6', '4.9', '7', '8', '11.7', '11.3', '4.3',
#        '4.1', '8.3', '4.2', '10.9', '9.5', '18.5', '13.2', '13.8', '17.2',
#        '15.7', '19', '9.6', '16.6', '15.5', '7.5', '10.8', '3.5', '16',
#        '3.8', '5.1', '11.5', '12.2', '14.3', '13.1', '8.1', '9.8', '9.1',
#        '14.2', '11.2'], dtype=object)

# %%
df_copy['ISI'] = df_copy['ISI'].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 28.7+ KB

# %%
cols = ['day','month','year']
df_copy[cols] = df_copy[cols].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(7), int64(8)
# memory usage: 28.7 KB

# %%
df_copy.to_csv("Algerian_forest_fires_dataset_cleaned.csv", index= False)
